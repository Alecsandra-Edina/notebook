# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Alecsandra** <br>
# Student

# %% [markdown]
# *I am interested in data science because I love working with data and getting insights, discovering patterns. I also like being able to tell a story and in the end solve problems. I like programming and statistics as well so I belive that data science is just right for me.*

# %% [markdown]
# ### The code in cell 5 defines a function that adds two numbers and then the function is called

# %%
def add(x,y):
    return x + y
add(8956,568)
# Out:
# 9524

# %% [markdown]
# 1. This is the first element.
# 2. This is the second element.
# 3. This is the third element.
# 4. This is the last element. <br>
#
# ---
#
# `This is something highlighted.`
#
# ~~And this is something else.~~
